# %%
#Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas.

import pandas as pd

# %%
#Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0".

df_videogames = pd.read_csv("videogames.csv")

df_videogames = pd.read_csv("videogames.csv", index_col = 0)

df_videogames
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %%
#Una vez creado el Dataframe, muestra las 10 primeras filas.

df_videogames.head(11)

# %%
#¿Cúal es el último índice que tenemos en el Dataframe?

df_videogames.info()

# %%
#Mostrar 15 filas aleatorias.

df_videogames.sample(15)
# Out:
#                                          name  \
# 14562                          Getsu Fûma Den
# 20780                       Monitor: The Game
# 10875                          Rune Factory 4
# 3645           Rygar: The Legendary Adventure
# 8407                                Megaforce
# 1373    102 Dalmatians: Puppies to the Rescue
# 13169                      Stargate Adventure
# 15358        Job Simulator: The 2050 Archives
# 6562                                 Napoleon
# 11718                        Days of Oblivion
# 14896                     Panzer Dragoon Orta
# 13871                                Qui Domi
# 16543      Who Wants to Be King of the Jungle
# 2832   Cowboy Bebop: Serenade of Reminiscence
# 10839                                 Frogger
#
#                                                      url    year certificate  \
# 14562  https://www.imdb.com/title/tt9649318/?ref_=adv...  1987.0         NaN
# 20780  https://www.imdb.com/title/tt7419456/?ref_=adv...  2017.0         NaN
# 10875  https://www.imdb.com/title/tt4203732/?ref_=adv...  2012.0        E10+
# 3645   https://www.imdb.com/title/tt0360942/?ref_=adv...  2002.0           T
# 8407   https://www.imdb.com/title/tt2310115/?ref_=adv...  1984.0         NaN
# 1373   https://www.imdb.com/title/tt0272423/?ref_=adv...  2000.0           E
# 13169  https://www.imdb.com/title/tt8057218/?ref_=adv...  2005.0         NaN
# 15358  https://www.imdb.com/title/tt7571518/?ref_=adv...  2016.0        E10+
# 6562   https://www.imdb.com/title/tt9480260/?ref_=adv...  2001.0         NaN
# 11718  https://www.imdb.com/title/tt5586546/?ref_=adv...  1996.0           M
# 14896  https://www.imdb.com/title/tt0349934/?ref_=adv...  2002.0           T
# 13871  https://www.imdb.com/title/tt5986062/?ref_=adv...  2017.0         NaN
# 16543  https://www.imdb.com/title/tt3231690/?ref_=adv...  2004.0         NaN
# 2832   https://www.imdb.com/title/tt0965597/?ref_=adv...  2005.0   Not Rated
# 10839  https://www.imdb.com/title/tt0294587/?ref_=adv...  1997.0           E
#
#        rating votes                                               plot  \
# 14562     NaN   NaN                                         Add a Plot
# 20780     NaN   NaN                                         Add a Plot
# 10875     8.1    36                                         Add a Plot
# 3645      7.3    44  Princess Harmonia has been kidnapped by the Ti...
# 8407      5.2    23                                         Add a Plot
# 1373      6.7   190  Oddball and Domino are two young Dalmatian pup...
# 13169     NaN   NaN  Fan made adventure game based on the Stargate ...
# 15358     7.5    94  In the year 2050, where robots are used for al...
# 6562      NaN   NaN                                         Add a Plot
# 11718     NaN   NaN  Tongue in cheek FMV adventure game with some m...
# 14896     7.8    94  Having lived imprisoned her entire life, a you...
# 13871     NaN   NaN  Annabelle was wandering about in her own room ...
# 16543     4.2    10                                         Add a Plot
# 2832      8.2    50  The game follows an original story set in the ...
# 10839     6.9   150  In this remake of the original of 1981, Frogge...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 14562   False       True   False  False   False    False    False   False
# 20780   False      False   False  False   False    False    False   False
# 10875   False       True   False  False   False    False    False   False
# 3645     True       True   False  False   False     True    False   False
# 8407     True      False   False  False   False    False    False    True
# 1373     True      False    True  False    True    False    False   False
# 13169   False       True   False  False   False    False    False    True
# 15358   False      False    True  False   False    False    False   False
# 6562     True      False   False  False   False    False    False   False
# 11718   False       True   False  False   False    False    False    True
# 14896    True       True   False  False   False    False    False   False
# 13871   False       True   False  False   False     True    False   False
# 16543   False      False   False  False    True    False    False   False
# 2832     True       True   False   True   False    False    False   False
# 10839   False       True   False  False    True    False    False   False
#
#        Thriller
# 14562     False
# 20780      True
# 10875     False
# 3645      False
# 8407      False
# 1373      False
# 13169     False
# 15358     False
# 6562      False
# 11718     False
# 14896     False
# 13871     False
# 16543     False
# 2832      False
# 10839     False

# %%
#Crea una lista con el nombre de las columnas.
df_videogames.columns.tolist()
# Out:
# ['name',
#  'url',
#  'year',
#  'certificate',
#  'rating',
#  'votes',
#  'plot',
#  'Action',
#  'Adventure',
#  'Comedy',
#  'Crime',
#  'Family',
#  'Fantasy',
#  'Mystery',
#  'Sci-Fi',
#  'Thriller']

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\profile1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\profile1\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openpyxl) (1.1.0)
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\profile1\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
#Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?
df_videogames.to_excel("videogames.xlsx")

# %%
#Muestra la "info" del Dataframe.
df_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

df_videogames_excel
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4      https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# ...                                                  ...     ...         ...
# 20798  https://www.imdb.com/title/tt3845606/?ref_=adv...  2014.0         NaN
# 20799  https://www.imdb.com/title/tt0790739/?ref_=adv...  2004.0         NaN
# 20800  https://www.imdb.com/title/tt5119948/?ref_=adv...  2015.0         NaN
# 20801  https://www.imdb.com/title/tt5142082/?ref_=adv...  2015.0         NaN
# 20802  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0         NaN
#
#        rating   votes                                               plot  \
# 0         9.2  20,759  When a new villain threatens New York City, Pe...
# 1         9.7  35,703  Amidst the decline of the Wild West at the tur...
# 2         9.5  59,986  Three very different criminals team up for a s...
# 3         9.6  26,118  After wiping out the gods of Mount Olympus, Kr...
# 4         9.5  28,722  Thrown back into the dangerous underworld he'd...
# ...       ...     ...                                                ...
# 20798     NaN     NaN                                         Add a Plot
# 20799     NaN     NaN  Joseph gets kidnapped and it's the player's jo...
# 20800     NaN     NaN  A tech support man who uses a drone to investi...
# 20801     NaN     NaN  A young teenage girl and the ghost of a dead m...
# 20802     NaN     NaN  Kidnapped by an insane man and dragged into a ...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 0        True       True   False  False   False     True    False   False
# 1        True       True   False   True   False    False    False   False
# 2        True      False   False   True   False    False    False   False
# 3        True       True   False  False   False    False    False   False
# 4        True       True   False  False   False    False    False   False
# ...       ...        ...     ...    ...     ...      ...      ...     ...
# 20798   False      False   False  False   False    False    False   False
# 20799   False      False   False  False   False    False    False   False
# 20800   False      False   False  False   False    False    False   False
# 20801   False      False   False  False   False    False    False   False
# 20802   False      False   False  False   False    False    False   False
#
#        Thriller
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...         ...
# 20798      True
# 20799      True
# 20800      True
# 20801      True
# 20802      True
#
# [20803 rows x 16 columns]

# %%
#¿Tiene nulos o duplicados?
#df_videogames_excel.isnull().sum()
df_videogames_excel.isna().sum()

# %%
df_videogames_excel.duplicated().sum()
# Out:
# 1

# %%
#Obtener la descripción del Dataframe, tanto de las columnas numéricas cómo de las de tipo "object". Explorar el resultado y sacar unas mínimas comclusiones sobre los datos que habéis obtenido.
df_videogames_excel.describe(include="object")
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %%
df_videogames_excel["name"].value_counts()
# Out:
# name
# Spider-Man                        9
# God of War                        6
# Sonic the Hedgehog                6
# Star Trek                         6
# Resident Evil 2                   5
#                                  ..
# Elevator Action                   1
# Nobuyuki Forces 4                 1
# Cross Fire: king of gun battle    1
# Duke: Nuclear Winter              1
# Cryptic                           1
# Name: count, Length: 19714, dtype: int64

# %%
#Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original.
df_videogames_excel.to_csv("videogames.csv")
